# %% [markdown]
# # %run

# %% [markdown]
# ## %run命令可以实现从计算机中调用代码/函数来运行

# %%
# %run E:\Python\Example_02_function\dwx_01_99乘法表.py
# Out:
# 1 * 1 = 1
# 1 * 2 = 2	2 * 2 = 4
# 1 * 3 = 3	2 * 3 = 6	3 * 3 = 9
# 1 * 4 = 4	2 * 4 = 8	3 * 4 = 12	4 * 4 = 16
# 1 * 5 = 5	2 * 5 = 10	3 * 5 = 15	4 * 5 = 20	5 * 5 = 25
# 1 * 6 = 6	2 * 6 = 12	3 * 6 = 18	4 * 6 = 24	5 * 6 = 30	6 * 6 = 36
# 1 * 7 = 7	2 * 7 = 14	3 * 7 = 21	4 * 7 = 28	5 * 7 = 35	6 * 7 = 42	7 * 7 = 49
# 1 * 8 = 8	2 * 8 = 16	3 * 8 = 24	4 * 8 = 32	5 * 8 = 40	6 * 8 = 48	7 * 8 = 56	8 * 8 = 64
# 1 * 9 = 9	2 * 9 = 18	3 * 9 = 27	4 * 9 = 36	5 * 9 = 45	6 * 9 = 54	7 * 9 = 63	8 * 9 = 72	9 * 9 = 81

# %% [markdown]
# # %timeit

# %%
# %timeit L = [i * 2 for i in range(1000)]
# Out:
# 61.3 µs ± 287 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [raw]
# 上面的结果表示：代码运行1000个循环，选取其中的7个循环，每个循环的平均值+-标准差，度量单行代码

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n ** 2)
# Out:
# 371 µs ± 2.42 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [raw]
# 度量一段程序

# %% [markdown]
# # time

# %%
# %time N = [i * 2 for i in range(1000)]  # 代码运行一次，运行时间有一定的误差
# Out:
# Wall time: 1e+03 µs

# %%
# %%time
L = []
for n in range(1000):
    L.append(n ** 2)
# Out:
# Wall time: 2 ms

# %%
import random
P = [random.random() for i in range(100000)]
# %timeit P.sort()
# Out:
# 588 µs ± 10.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
